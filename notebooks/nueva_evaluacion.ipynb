# %% [markdown]
# ## Triste

# %%
import sys
sys.path.append('..')
from datasets import KusisqaDim
from datasets.utils import randomcrop, centercrop
from torch.utils.data import DataLoader
from torchmetrics import MeanAbsoluteError

dataset_train = KusisqaDim(
    "../ser_datasets/test_kusisqa/audio-triste.csv",
    "../ser_datasets/test_kusisqa/Audio-Triste/",
    transform=[centercrop],
)

train_dataloader = DataLoader(
    dataset_train,
    batch_size=32,
    shuffle=False,
    num_workers=3,
    persistent_workers=True,
)

for x,y in train_dataloader:
    print(x.shape, y.shape)
    break

path_pesos = "../checkpoints/flower.ckpt"
from models.cnn_dim import CNNDim
from models.metrics import CCC, ccc

model = CNNDim.load_from_checkpoint(path_pesos,lr=0.001)
model.eval()

metric = MeanAbsoluteError()

ccc_v = CCC()
ccc_a = CCC()
ccc_d = CCC()

for x,y in train_dataloader:
  resultado = model(x)
  
  acc = metric(resultado, y)

  mccc_v = ccc(resultado[:, 0], y[:, 0])
  mccc_a = ccc(resultado[:, 1], y[:, 1])
  mccc_d = ccc(resultado[:, 2], y[:, 2])

  ccc_v(mccc_v)
  ccc_a(mccc_a)
  ccc_d(mccc_d)


  for i in range(len(resultado)):
    print(resultado[i].data, y[i])
    
  print(f"MAE batch: { acc}")

  print(f"CCC V batch: { mccc_v}")
  print(f"CCC A batch: { mccc_a}")
  print(f"CCC D batch: { mccc_d}\n")

  
acc = metric.compute()
mccc_a = ccc_a.compute()
mccc_v = ccc_v.compute()
mccc_d = ccc_d.compute()

print(f"MAE: { acc}")
print(f"CCC V: { mccc_v}")
print(f"CCC A : { mccc_a}")
print(f"CCC D : { mccc_d}")

# Plot confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# Out:
# torch.Size([32, 64, 128]) torch.Size([32, 3])
# tensor([1.1971, 2.3734, 1.7973]) tensor([3., 1., 2.])
# tensor([1.5289, 1.9064, 2.0531]) tensor([3., 1., 2.])
# tensor([1.6092, 2.2429, 2.0536]) tensor([3., 1., 4.])
# tensor([1.6721, 2.7988, 2.1829]) tensor([3., 1., 4.])
# tensor([0.2473, 3.2732, 1.1962]) tensor([1., 2., 1.])
# tensor([1.3738, 3.0098, 2.3785]) tensor([1., 2., 1.])
# tensor([1.2797, 2.7084, 1.8717]) tensor([1., 2., 1.])
# tensor([1.6935, 1.9569, 2.3324]) tensor([1., 2., 1.])
# tensor([1.2349, 2.7425, 1.8202]) tensor([1., 2., 1.])
# tensor([1.4915, 2.0907, 1.9435]) tensor([1., 2., 1.])
# tensor([2.3762, 2.1761, 2.7596]) tensor([1., 2., 1.])
# tensor([1.3939, 2.3153, 2.2033]) tensor([1., 2., 1.])
# tensor([1.3348, 2.3790, 2.1377]) tensor([1., 2., 1.])
# tensor([1.5908, 2.5098, 2.1831]) tensor([1., 2., 1.])
# tensor([1.7497, 2.1137, 1.9633]) tensor([1., 2., 1.])
# tensor([1.0341, 2.7343, 1.7694]) tensor([1., 2., 1.])
# tensor([1.9815, 2.1989, 2.4973]) tensor([1., 2., 1.])
# tensor([1.4355, 3.0477, 2.0564]) tensor([1., 2., 1.])
# tensor([2.6276, 2.4974, 2.5283]) tensor([1., 2., 1.])
# tensor([1.3081, 2.2290, 1.9731]) tensor([1., 2., 1.])
# tensor([1.5524, 2.1432, 1.9823]) tensor([1., 2., 1.])
# tensor([1.2987, 2.0616, 1.6961]) tensor([2., 1., 2.])
# tensor([1.1365, 2.6586, 2.0766]) tensor([1., 2., 1.])
# tensor([1.1739, 2.5190, 2.3094]) tensor([1., 2., 1.])
# tensor([2.3186, 2.4262, 2.8319]) tensor([1., 2., 1.])
# tensor([1.1151, 2.5720, 1.9800]) tensor([2., 1., 2.])
# tensor([1.8277, 2.9674, 3.3131]) tensor([3., 1., 2.])
# tensor([1.5703, 2.9209, 2.4105]) tensor([1., 2., 1.])
# tensor([2.7807, 2.0071, 3.1363]) tensor([1., 2., 2.])
# tensor([1.6905, 2.6080, 2.8525]) tensor([2., 1., 2.])
# tensor([2.1938, 2.6236, 2.7801]) tensor([2., 1., 2.])
# tensor([1.2405, 2.3343, 1.8450]) tensor([2., 1., 2.])
# MAE batch: 0.8566872477531433
# CCC V batch: -0.019682642072439194
# CCC A batch: 0.016414670273661613
# CCC D batch: 0.042369794100522995
#
# tensor([2.4749, 2.8435, 3.0710]) tensor([2., 1., 2.])
# tensor([1.2299, 1.9699, 1.7224]) tensor([3., 1., 2.])
# tensor([1.3555, 3.0863, 2.5335]) tensor([3., 1., 2.])
# tensor([1.3575, 2.3233, 2.0674]) tensor([3., 1., 2.])
# tensor([2.0361, 2.4427, 2.3818]) tensor([3., 1., 4.])
# tensor([2.0374, 1.7356, 2.3117]) tensor([3., 1., 4.])
# tensor([2.6014, 2.0444, 3.9308]) tensor([3., 2., 4.])
# tensor([1.5879, 2.4347, 2.5569]) tensor([3., 1., 4.])
# tensor([1.7039, 1.9140, 2.3661]) tensor([3., 1., 4.])
# tensor([1.3623, 1.8876, 2.0031]) tensor([3., 1., 4.])
# tensor([2.4200, 3.6335, 2.6300]) tensor([2., 1., 2.])
# tensor([0.4532, 3.6975, 1.6953]) tensor([1., 2., 1.])
# tensor([1.0677, 3.9747, 2.1825]) tensor([1., 2., 1.])
# tensor([1.6566, 2.3718, 1.9764]) tensor([1., 2., 1.])
# tensor([1.8044, 2.3081, 2.3592]) tensor([2., 1., 2.])
# tensor([1.3546, 1.8939, 1.7371]) tensor([1., 2., 1.])
# tensor([1.4405, 2.2060, 2.1362]) tensor([1., 2., 1.])
# tensor([1.3564, 2.5151, 2.0117]) tensor([1., 2., 1.])
# tensor([1.7998, 2.1863, 2.6188]) tensor([2., 1., 2.])
# tensor([1.8458, 2.5748, 2.3592]) tensor([2., 1., 2.])
# tensor([1.4276, 2.0016, 1.9336]) tensor([2., 1., 2.])
# tensor([1.3453, 2.2520, 1.9091]) tensor([2., 1., 2.])
# tensor([1.6329, 2.3380, 2.5578]) tensor([3., 1., 3.])
# tensor([1.3915, 2.2144, 1.8089]) tensor([3., 1., 3.])
# tensor([1.1510, 2.8040, 1.6124]) tensor([2., 1., 2.])
# tensor([1.3901, 2.2965, 2.1266]) tensor([2., 1., 2.])
# tensor([1.3095, 2.6911, 2.2031]) tensor([2., 1., 2.])
# tensor([1.8455, 2.2012, 2.1287]) tensor([2., 1., 2.])
# tensor([1.6692, 2.3718, 2.2395]) tensor([2., 1., 2.])
# tensor([1.3533, 3.1654, 1.9953]) tensor([2., 1., 1.])
# MAE batch: 0.9183199405670166
# CCC V batch: 0.19287781417369843
# CCC A batch: 0.04545978829264641
# CCC D batch: 0.323440819978714
#
# MAE: 0.8865095376968384
# CCC V: 0.08659758418798447
# CCC A : 0.030937228351831436
# CCC D : 0.18290530145168304

# %% [markdown]
# ## Alegre

# %%
dataset_train = KusisqaDim(
    "../ser_datasets/test_kusisqa/audio-alegre.csv",
    "../ser_datasets/test_kusisqa/Audio-Alegre/",
    transform=[centercrop],
)

train_dataloader = DataLoader(
    dataset_train,
    batch_size=32,
    shuffle=False,
    num_workers=3,
    persistent_workers=True,
)

for x,y in train_dataloader:
    print(x.shape, y.shape)
    break

path_pesos = "../checkpoints/flower.ckpt"
from models.cnn_dim import CNNDim
from models.metrics import CCC

model = CNNDim.load_from_checkpoint(path_pesos,lr=0.001)
model.eval()

metric = MeanAbsoluteError()

ccc_v = CCC()
ccc_a = CCC()
ccc_d = CCC()

for x,y in train_dataloader:
  resultado = model(x)
  
  acc = metric(resultado, y)

  mccc_v = ccc(resultado[:, 0], y[:, 0])
  mccc_a = ccc(resultado[:, 1], y[:, 1])
  mccc_d = ccc(resultado[:, 2], y[:, 2])

  ccc_v(mccc_v)
  ccc_a(mccc_a)
  ccc_d(mccc_d)


  # for i in range(len(resultado)):
  #   print(resultado[i].data, y[i])
    
  print(f"MAE batch: { acc}")

  print(f"CCC V batch: { mccc_v}")
  print(f"CCC A batch: { mccc_a}")
  print(f"CCC D batch: { mccc_d}\n")

  
acc = metric.compute()
mccc_a = ccc_a.compute()
mccc_v = ccc_v.compute()
mccc_d = ccc_d.compute()

print(f"MAE: { acc}")
print(f"CCC V: { mccc_v}") 
print(f"CCC A : { mccc_a}")
print(f"CCC D : { mccc_d}")
# Out:
# torch.Size([32, 64, 128]) torch.Size([32, 3])
# MAE batch: 0.8071368336677551
# CCC V batch: 0.07900616526603699
# CCC A batch: 0.3999749720096588
# CCC D batch: 0.0535859577357769
#
# MAE batch: 0.8884741067886353
# CCC V batch: 0.18282510340213776
# CCC A batch: 0.20438623428344727
# CCC D batch: 0.0
#
# MAE: 0.8464936017990112
# CCC V: 0.13091564178466797
# CCC A : 0.30218058824539185
# CCC D : 0.02679297886788845
